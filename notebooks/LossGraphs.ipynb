         0.7654, 0.8214, 0.6796, 0.7833, 0.6621, 0.6972, 0.6878, 0.6896, 0.6599,
         0.6796, 0.6537, 0.6222, 0.6466, 0.6680, 0.6435, 0.6391, 0.6293, 0.6324,
         0.6377, 0.6372, 0.6814, 0.6536, 0.6371, 0.6181, 0.6445, 0.6558, 0.6321,
         0.7037, 0.6560, 0.6414, 0.6425, 0.6257, 0.7542, 0.6332, 0.6590, 0.6428,
         0.6175, 0.6637, 0.6098, 0.6347, 0.6497, 0.6231, 0.6373, 0.6388, 0.6654,
         0.6579, 0.6359, 0.6415, 0.6471, 0.6254, 0.6762, 0.6301, 0.6204, 0.6841,
         0.6470, 0.6576, 0.7151, 0.6783, 0.6474, 0.7400, 0.6452, 0.6454, 0.6208,
         0.6232, 0.6349]]), tensor([3.3537, 1.6712, 1.4824, 0.9992, 1.0731, 1.3028, 1.6286, 1.0344, 0.8460,
        1.0936, 1.2609, 0.7935, 0.7857, 0.7391, 0.7809, 0.8228, 0.8481, 0.7477,
        0.7655, 0.7328, 0.7015, 1.0144, 0.8650, 0.8168, 0.7473, 0.7569, 0.8211,
        0.7594, 0.8120, 0.6971, 0.7982, 0.7341, 0.6395, 0.7491, 0.9702, 0.7372,
        0.7654, 0.8214, 0.6796, 0.7833, 0.6621, 0.6972, 0.6878, 0.6896, 0.6599,
        0.6796, 0.6537, 0.6222, 0.6466, 0.6680, 0.6435, 0.6391, 0.6293, 0.6324,
        0.6377, 0.6372, 0.6814, 0.6536, 0.6371, 0.6181, 0.6445, 0.6558, 0.6321,
        0.7037, 0.6560, 0.6414, 0.6425, 0.6257, 0.7542, 0.6332, 0.6590, 0.6428,
        0.6175, 0.6637, 0.6098, 0.6347, 0.6497, 0.6231, 0.6373, 0.6388, 0.6654,
        0.6579, 0.6359, 0.6415, 0.6471, 0.6254, 0.6762, 0.6301, 0.6204, 0.6841,
        0.6470, 0.6576, 0.7151, 0.6783, 0.6474, 0.7400, 0.6452, 0.6454, 0.6208,
        0.6232, 0.6349]), tensor(74)), tensor([0.7149]))

# %%
b_contrastive_loss = b_loss[0][0].tolist()[0]
epochs = list(range(0, 101))

# %%
b_prediction_loss[-1]
# Out:
# 0.6348999738693237

# %%
sns.set()
sns.lineplot(x=epochs, y=b_contrastive_loss)
plt.title("IMBD-BINARY: Contrastive Loss per Epoch", fontsize=18)
plt.xlabel("Epochs")
plt.ylabel("NT-Xent Loss")

plt.savefig('imdb_binary_contrastive_loss.png', dpi=300)

plt.show()

# %%
b_prediction_loss = b_loss[1][0].tolist()[0]
epochs = list(range(0, 101))

# %%
b_prediction_loss[-1]
# Out:
# 0.6348999738693237

# %%
sns.set()
sns.lineplot(x=epochs, y=b_prediction_loss)
plt.title("IMBD-BINARY: Prediction Loss per Epoch", fontsize=18)
plt.xlabel("Epochs")
plt.ylabel("NLL Loss")

plt.savefig('imdb_binary_prediction_loss.png', dpi=300)

         1.1600, 1.2410, 1.2393, 1.2200, 1.1910, 1.1214, 1.0847, 1.1668, 1.0782,
         1.3485, 1.2183, 1.1899, 1.0329, 1.0859, 1.0630, 1.0166, 1.1576, 1.2473,
         1.0243, 1.0533, 1.2821, 1.0970, 1.0229, 1.0751, 1.0695, 1.1060, 1.0273,
         1.0042, 1.0796, 1.0806, 1.2712, 1.1556, 1.0975, 1.0968, 0.9792, 1.0090,
         1.0945, 1.0534, 1.0441, 0.9949, 1.0687, 1.0072, 1.1809, 1.0370, 1.0096,
         1.1885, 1.0155, 0.9930, 1.0073, 1.0001, 1.0773, 0.9736, 1.0986, 1.2780,
         1.0408, 1.0055, 1.0356, 1.0221, 1.0455, 0.9934, 0.9918, 1.0606, 1.0292,
         1.0347, 1.0618]]), tensor([3.0778, 2.0643, 1.7682, 1.7737, 1.5051, 1.5268, 1.4806, 1.3063, 1.3676,
        1.2845, 1.2626, 1.5814, 1.3621, 1.1550, 1.1584, 1.4500, 1.2956, 1.2875,
        1.2211, 1.2396, 1.0794, 1.2504, 1.1189, 1.2330, 1.1587, 1.1843, 1.2987,
        1.2450, 1.2193, 1.1028, 1.1100, 1.1974, 1.5689, 1.2927, 1.3116, 1.3948,
        1.1600, 1.2410, 1.2393, 1.2200, 1.1910, 1.1214, 1.0847, 1.1668, 1.0782,
        1.3485, 1.2183, 1.1899, 1.0329, 1.0859, 1.0630, 1.0166, 1.1576, 1.2473,
        1.0243, 1.0533, 1.2821, 1.0970, 1.0229, 1.0751, 1.0695, 1.1060, 1.0273,
        1.0042, 1.0796, 1.0806, 1.2712, 1.1556, 1.0975, 1.0968, 0.9792, 1.0090,
        1.0945, 1.0534, 1.0441, 0.9949, 1.0687, 1.0072, 1.1809, 1.0370, 1.0096,
        1.1885, 1.0155, 0.9930, 1.0073, 1.0001, 1.0773, 0.9736, 1.0986, 1.2780,
        1.0408, 1.0055, 1.0356, 1.0221, 1.0455, 0.9934, 0.9918, 1.0606, 1.0292,
        1.0347, 1.0618]), tensor(87)), tensor([0.5413]))

# %%
m_contrastive_loss = m_loss[0][0].tolist()[0]
epochs = list(range(0, 101))

# %%
m_contrastive_loss[-1]
# Out:
# 0.794700026512146

# %%
sns.set()
sns.lineplot(x=epochs, y=m_contrastive_loss)
plt.title("IMBD-MULTI: Contrastive Loss per Epoch", fontsize=18)
plt.xlabel("Epochs")
plt.ylabel("NT-Xent Loss")

plt.savefig('imdb_multi_contrastive_loss.png', dpi=300)

plt.show()

# %%
m_prediction_loss = m_loss[1][0].tolist()[0]
epochs = list(range(0, 101))

# %%
m_prediction_loss[-1]
# Out:
# 1.0618000030517578

# %%
sns.set()
sns.lineplot(x=epochs, y=m_prediction_loss)
plt.title("IMBD-MULTI: Prediction Loss per Epoch", fontsize=18)
plt.xlabel("Epochs")
plt.ylabel("NLL Loss")

plt.savefig('imdb_multi_prediction_loss.png', dpi=300)

plt.show()
